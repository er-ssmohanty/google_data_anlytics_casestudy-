# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# #getwd()
# #setwd(list.files()[])
# #list.files()
# year=2018
# setwd(paste("/content/drive/MyDrive/tripdatcyc/",as.character(year),sep=""))

# %%
# %%R
# library("tidyverse")
# library("lubridate")
# Out:
# R[write to console]: ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# R[write to console]: ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.1.0     ✔ forcats 0.5.1
#
# R[write to console]: ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# R[write to console]:
# Attaching package: ‘lubridate’
#
#
# R[write to console]: The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union

# %%
# %%R
# list.files()
# Out:
# [1] "Divvy_Trips_2018_Q1.csv" "Divvy_Trips_2018_Q2.csv"
# [3] "Divvy_Trips_2018_Q3.csv" "Divvy_Trips_2018_Q4.csv"

# %%
# %%R
# trip18q1=read_csv("Divvy_Trips_2018_Q1.csv")
# trip18q2=read_csv("Divvy_Trips_2018_Q2.csv")
# trip18q3=read_csv("Divvy_Trips_2018_Q3.csv")
# trip18q4=read_csv("Divvy_Trips_2018_Q4.csv")
# Out:
# Rows: 387145 Columns: 12
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (4): 03 - Rental Start Station Name, 02 - Rental End Station Name, User...
# dbl  (5): 01 - Rental Details Rental ID, 01 - Rental Details Bike ID, 03 - R...
# dttm (2): 01 - Rental Details Local Start Time, 01 - Rental Details Local En...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 1059681 Columns: 12
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (4): from_station_name, to_station_name, usertype, gender
# dbl  (5): trip_id, bikeid, from_station_id, to_station_id, birthyear
# dttm (2): start_time, end_time
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# ...

# %%
# %%R
# names(trip18q1)=names(trip18q2)

# %%
# %%R
# trip18 = rbind(trip18q1,trip18q2,trip18q3,trip18q4)

# %%
# %%R
# unique(month(trip18$end_time))
# Out:
#  [1]  1  6  3  7  2  5  4  8  9 11 10 12

# %%
# %%R
# ggplot(data=trip21)+geom_histogram(stat="count",mapping=aes(x=month(started_at),fill=member_casual))

# %%
# %%R
# ggplot(data=trip21)+geom_histogram(stat="count",mapping=aes(x=month(started_at),fill=member_casual))

# %%
# %%R
# ggplot(data=trip21)+geom_histogram(stat="count",mapping=aes(x=month(start_time)))

# %%
# %%R
# dim(trip21)
# Out:
# [1] 3603082      12

# %%
# %%R
# length(unique(trip21$trip_id))
# Out:
# [1] 3603082

# %%
# %%R
# names(trip18)
# Out:
#  [1] "trip_id"           "start_time"        "end_time"
#  [4] "bikeid"            "tripduration"      "from_station_id"
#  [7] "from_station_name" "to_station_id"     "to_station_name"
# [10] "usertype"          "gender"            "birthyear"

# %%
# %%R
# trip18=trip18[,c(-11,-12)]

# %%
# %%R
# names(trip18)
# Out:
#  [1] "trip_id"           "start_time"        "end_time"
#  [4] "bikeid"            "tripduration"      "from_station_id"
#  [7] "from_station_name" "to_station_id"     "to_station_name"
# [10] "usertype"

# %%
# %%R
# #setwd("..")
# write_csv(trip18,"triptotal18.csv")

# %%
# %%R
# asd=c(2,3,5,7,11,13)
# asd[-4]
# Out:
# [1]  2  3  5 11 13
