# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# library(tidyverse)
# #library(lubridate)
# Out:
# R[write to console]: ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# R[write to console]: ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.1.1     ✔ forcats 0.5.1
#
# R[write to console]: ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
# %%R
# setwd("/content/drive/MyDrive/tripdatcyc")
# list.files()
# Out:
#  [1] "2013"               "2014"               "2015"
#  [4] "2016"               "2017"               "2018"
#  [7] "2019"               "2020"               "2021"
# [10] "triptotal13.csv"    "triptotal13.gsheet" "triptotal14.csv"
# [13] "triptotal15.csv"    "triptotal16.csv"    "triptotal17.csv"
# [16] "triptotal18.csv"    "triptotal19.csv"    "triptotal20.csv"
# [19] "triptotal21.csv"

# %%
# %%R
# t13 = read_csv("triptotal13.csv")
# t14 = read_csv("triptotal14.csv")
# t15 = read_csv("triptotal15.csv")
# t16 = read_csv("triptotal16.csv")
# t17 = read_csv("triptotal17.csv")
# t18 = read_csv("triptotal18.csv")
# t19 = read_csv("triptotal19.csv")
# t20 = read_csv("triptotal20.csv")
# t21 = read_csv("triptotal21.csv")
# Out:
# Rows: 759788 Columns: 12
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (4): from_station_name, to_station_name, usertype, gender
# dbl  (6): trip_id, bikeid, tripduration, from_station_id, to_station_id, bir...
# dttm (2): starttime, stoptime
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 2454634 Columns: 10
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (3): from_station_name, to_station_name, usertype
# dbl  (5): trip_id, bikeid, tripduration, from_station_id, to_station_id
# dttm (2): starttime, stoptime
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 3183439 Columns: 10
# ...

# %%
# %%R
# print(names(t13))
# print(names(t14))
# print(names(t15))
# print(names(t16))
# print(names(t17))
# print(names(t18))
# print(names(t19))
# print(names(t20))
# print(names(t21))
# Out:
#  [1] "trip_id"           "starttime"         "stoptime"
#  [4] "bikeid"            "tripduration"      "from_station_id"
#  [7] "from_station_name" "to_station_id"     "to_station_name"
# [10] "usertype"          "gender"            "birthday"
#  [1] "trip_id"           "starttime"         "stoptime"
#  [4] "bikeid"            "tripduration"      "from_station_id"
#  [7] "from_station_name" "to_station_id"     "to_station_name"
# [10] "usertype"
#  [1] "trip_id"           "starttime"         "stoptime"
#  [4] "bikeid"            "tripduration"      "from_station_id"
#  [7] "from_station_name" "to_station_id"     "to_station_name"
# [10] "usertype"
#  [1] "trip_id"           "starttime"         "stoptime"
#  [4] "bikeid"            "tripduration"      "from_station_id"
#  [7] "from_station_name" "to_station_id"     "to_station_name"
# [10] "usertype"
#  [1] "trip_id"           "start_time"        "end_time"
#  [4] "bikeid"            "tripduration"      "from_station_id"
# ...

# %%
# %%R
# t13 = t13[,c(-11,-12)]
# t19 = t19[,c(-11,-12)]

# %%
# %%R
# print(names(t13))
# print(names(t14))
# print(names(t15))
# print(names(t16))
# print(names(t17))
# print(names(t18))
# print(names(t19))
# print(names(t20))
# print(names(t21))
# Out:
#  [1] "trip_id"           "starttime"         "stoptime"
#  [4] "bikeid"            "tripduration"      "from_station_id"
#  [7] "from_station_name" "to_station_id"     "to_station_name"
# [10] "usertype"
#  [1] "trip_id"           "starttime"         "stoptime"
#  [4] "bikeid"            "tripduration"      "from_station_id"
#  [7] "from_station_name" "to_station_id"     "to_station_name"
# [10] "usertype"
#  [1] "trip_id"           "starttime"         "stoptime"
#  [4] "bikeid"            "tripduration"      "from_station_id"
#  [7] "from_station_name" "to_station_id"     "to_station_name"
# [10] "usertype"
#  [1] "trip_id"           "starttime"         "stoptime"
#  [4] "bikeid"            "tripduration"      "from_station_id"
#  [7] "from_station_name" "to_station_id"     "to_station_name"
# [10] "usertype"
#  [1] "trip_id"           "start_time"        "end_time"
#  [4] "bikeid"            "tripduration"      "from_station_id"
# ...

# %%
# %%R
# print(identical(names(t13),names(t14)))
# print(identical(names(t13),names(t15)))
# print(identical(names(t13),names(t16)))
# print(identical(names(t13),names(t17)))
# print(identical(names(t13),names(t18)))
# print(identical(names(t13),names(t19)))
# Out:
# [1] TRUE
# [1] TRUE
# [1] TRUE
# [1] FALSE
# [1] FALSE
# [1] FALSE

# %%
# %%R
# names(t17) = names(t13)
# names(t18) = names(t13)
# names(t19) = names(t13)

# %%
# %%R
# print(identical(names(t13),names(t14)))
# print(identical(names(t13),names(t15)))
# print(identical(names(t13),names(t16)))
# print(identical(names(t13),names(t17)))
# print(identical(names(t13),names(t18)))
# print(identical(names(t13),names(t19)))
# Out:
# [1] TRUE
# [1] TRUE
# [1] TRUE
# [1] TRUE
# [1] TRUE
# [1] TRUE

# %%
# %%R
# head(t20)
# Out:
# # A tibble: 6 × 13
#   ride_id rideable_type started_at          ended_at            start_station_n…
#   <chr>   <chr>         <dttm>              <dttm>              <chr>
# 1 EACB19… docked_bike   2020-01-21 20:06:59 2020-01-21 20:14:30 Western Ave & L…
# 2 8FED87… docked_bike   2020-01-30 14:22:39 2020-01-30 14:26:22 Clark St & Mont…
# 3 789F3C… docked_bike   2020-01-09 19:29:26 2020-01-09 19:32:17 Broadway & Belm…
# 4 C9A388… docked_bike   2020-01-06 16:17:07 2020-01-06 16:25:56 Clark St & Rand…
# 5 943BC3… docked_bike   2020-01-30 08:37:16 2020-01-30 08:42:48 Clinton St & La…
# 6 6D9C8A… docked_bike   2020-01-10 12:33:05 2020-01-10 12:37:54 Wells St & Hubb…
# # … with 8 more variables: start_station_id <chr>, end_station_name <chr>,
# #   end_station_id <chr>, start_lat <dbl>, start_lng <dbl>, end_lat <dbl>,
# #   end_lng <dbl>, member_casual <chr>

# %%
# %%R
# str(t13)
# str(t14)
# str(t15)
# str(t16)
# str(t17)
# str(t18)
# str(t19)
# Out:
# tibble [759,788 × 10] (S3: tbl_df/tbl/data.frame)
#  $ trip_id          : num [1:759788] 4118 4275 4291 4316 4342 ...
#  $ starttime        : POSIXct[1:759788], format: "2013-06-27 12:11:00" "2013-06-27 14:44:00" ...
#  $ stoptime         : POSIXct[1:759788], format: "2013-06-27 12:16:00" "2013-06-27 14:45:00" ...
#  $ bikeid           : num [1:759788] 480 77 77 77 77 27 418 170 353 369 ...
#  $ tripduration     : num [1:759788] 316 64 433 123 852 ...
#  $ from_station_id  : num [1:759788] 85 32 32 19 19 340 37 90 37 51 ...
#  $ from_station_name: chr [1:759788] "Michigan Ave & Oak St" "Racine Ave & Congress Pkwy" "Racine Ave & Congress Pkwy" "Loomis St & Taylor St" ...
#  $ to_station_id    : num [1:759788] 28 32 19 19 55 46 76 75 37 340 ...
#  $ to_station_name  : chr [1:759788] "Larrabee St & Menomonee St" "Racine Ave & Congress Pkwy" "Loomis St & Taylor St" "Loomis St & Taylor St" ...
#  $ usertype         : chr [1:759788] "Customer" "Customer" "Customer" "Customer" ...
# ...

# %%
# %%R
# t13to19 = rbind(t13,t14,t15,t16,t17,t18,t19)

# %%
# %%R
# identical(names(t20),names(t21))
# Out:
# [1] TRUE

# %%
# %%R
# t20_21 = rbind(t20,t21)

# %%
# %%R
# unique(year(t20_21$started_at))
# Out:
# [1] 2020 2021

# %%
# %%R
# rm(t13,t14,t15,t16,t17,t18,t19,t20,t21)

# %%
# %%R
# names(t20_21)
# Out:
#  [1] "ride_id"            "rideable_type"      "started_at"
#  [4] "ended_at"           "start_station_name" "start_station_id"
#  [7] "end_station_name"   "end_station_id"     "start_lat"
# [10] "start_lng"          "end_lat"            "end_lng"
# [13] "member_casual"

# %%
# %%R
# names(t13to19)
# Out:
#  [1] "trip_id"           "starttime"         "stoptime"
#  [4] "bikeid"            "tripduration"      "from_station_id"
#  [7] "from_station_name" "to_station_id"     "to_station_name"
# [10] "usertype"

# %%
# %%R
# t20_21 = t20_21[,c(-9,-10,-11,-12)]
# names(t20_21)
# Out:
# [1] "ride_id"            "rideable_type"      "started_at"
# [4] "ended_at"           "start_station_name" "start_station_id"
# [7] "end_station_name"   "end_station_id"     "member_casual"

# %%
# %%R
# head(t13to19)
# Out:
# # A tibble: 6 × 10
#   trip_id starttime           stoptime            bikeid tripduration
#     <dbl> <dttm>              <dttm>               <dbl>        <dbl>
# 1    4118 2013-06-27 12:11:00 2013-06-27 12:16:00    480          316
# 2    4275 2013-06-27 14:44:00 2013-06-27 14:45:00     77           64
# 3    4291 2013-06-27 14:58:00 2013-06-27 15:05:00     77          433
# 4    4316 2013-06-27 15:06:00 2013-06-27 15:09:00     77          123
# 5    4342 2013-06-27 15:13:00 2013-06-27 15:27:00     77          852
# 6    4480 2013-06-27 19:40:00 2013-06-27 22:28:00     27        10105
# # … with 5 more variables: from_station_id <dbl>, from_station_name <chr>,
# #   to_station_id <dbl>, to_station_name <chr>, usertype <chr>

# %%
# %%R
# as.numeric(difftime(head(t20_21)$ended_at,head(t20_21)$started_at,units="secs"))
# Out:
# [1] 451 223 171 529 332 289

# %%
# %%R
# tripduration20_21 =length(as.numeric(difftime(t20_21$ended_at,t20_21$started_at,units="secs")))
# identical(tripduration20_21,dim(t20_21)[1])
# Out:
# [1] TRUE

# %%
# %%R
# t20_21 = cbind(tripduration20_21,t20_21)
# names(t20_21)
# Out:
#  [1] "tripduration20_21"  "ride_id"            "rideable_type"
#  [4] "started_at"         "ended_at"           "start_station_name"
#  [7] "start_station_id"   "end_station_name"   "end_station_id"
# [10] "member_casual"

# %%
# %%R
# t13to19 = t13to19[,c(-4)]
# #t13to19$rideable_type = NA*Vector(lenth=dim(t13to19)[1])

# %%
# %%R
# t13to19$rideable_type = vector(length=dim(t13to19)[1])*NA

# %%
# %%R
# print(names(t13to19))
# print(names(t20_21))
# Out:
#  [1] "trip_id"           "starttime"         "stoptime"
#  [4] "tripduration"      "from_station_id"   "from_station_name"
#  [7] "to_station_id"     "to_station_name"   "usertype"
# [10] "rideable_type"
#  [1] "tripduration20_21"  "ride_id"            "rideable_type"
#  [4] "started_at"         "ended_at"           "start_station_name"
#  [7] "start_station_id"   "end_station_name"   "end_station_id"
# [10] "member_casual"

# %%
# %%R
# #rename
# names(t20_21)=c("tripduration","trip_id","rideable_type","starttime","stoptime","from_station_name","from_station_id",
#                 "to_station_name","to_station_id","usertype")
# print(names(t13to19))
# print(names(t20_21))
# Out:
#  [1] "trip_id"           "starttime"         "stoptime"
#  [4] "tripduration"      "from_station_id"   "from_station_name"
#  [7] "to_station_id"     "to_station_name"   "usertype"
# [10] "rideable_type"
#  [1] "tripduration"      "trip_id"           "rideable_type"
#  [4] "starttime"         "stoptime"          "from_station_name"
#  [7] "from_station_id"   "to_station_name"   "to_station_id"
# [10] "usertype"

# %%
# %%R
# #rearrange
# t13to19new <- t13to19 %>% select(names(t20_21))

# %%
# %%R
# identical(names(t13to19new),names(t20_21))
# Out:
# [1] TRUE

# %%
# %%R
# t13to19new = t13to19new[!duplicated(t13to19new[c('trip_id')]), ]
# write_csv(t13to19new,"trip13to19.csv")
# rm(t13to19new)

# %%
# %%R
# t20_21 = t20_21[!duplicated(t20_21[c('trip_id')]), ]
# write_csv(t20_21,"trip20to21.csv")
# rm(t20_21)

# %%
# %%R
# #unite
# totaltrip = rbind(t13to19new,t20_21)
# rm(t13to19new,t20_21)

# %%
# %%R
# str(totaltrip)
# Out:
# tibble [30,132,550 × 10] (S3: tbl_df/tbl/data.frame)
#  $ tripduration     : num [1:30132550] 316 64 433 123 852 ...
#  $ trip_id          : chr [1:30132550] "4118" "4275" "4291" "4316" ...
#  $ rideable_type    : chr [1:30132550] NA NA NA NA ...
#  $ starttime        : POSIXct[1:30132550], format: "2013-06-27 12:11:00" "2013-06-27 14:44:00" ...
#  $ stoptime         : POSIXct[1:30132550], format: "2013-06-27 12:16:00" "2013-06-27 14:45:00" ...
#  $ from_station_name: chr [1:30132550] "Michigan Ave & Oak St" "Racine Ave & Congress Pkwy" "Racine Ave & Congress Pkwy" "Loomis St & Taylor St" ...
#  $ from_station_id  : chr [1:30132550] "85" "32" "32" "19" ...
#  $ to_station_name  : chr [1:30132550] "Larrabee St & Menomonee St" "Racine Ave & Congress Pkwy" "Loomis St & Taylor St" "Loomis St & Taylor St" ...
#  $ to_station_id    : chr [1:30132550] "28" "32" "19" "19" ...
#  $ usertype         : chr [1:30132550] "Customer" "Customer" "Customer" "Customer" ...

# %%
# %%R
# unique(totaltrip$usertype)
# Out:
# [1] "Customer"   "Subscriber" "Dependent"  "member"     "casual"

# %%
#check unique counts and total counts, unique months, unique years
# %%R
print(length(unique(totaltrip$trip_id)))
print(dim(totaltrip)[1])
# Out:
# [1] 30132280
# [1] 30132550

# %%
# %%R
# ttnew = totaltrip[!duplicated(totaltrip[c('trip_id')]), ]
# rm(totaltrip)

# %%
# %%R
# print(length(unique(ttnew$trip_id)))
# print(dim(ttnew)[1])
# Out:
# [1] 30132280
# [1] 30132280

# %%
#graph histogram 
# %%R
ggplot(data=ttnew)+geom_histogram(mapping=aes(x=month(stoptime),fill=usertype))
# Out:
# R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %%
# %%R
# detach("package:lubridate", unload=TRUE)
# detach("package:tidyverse", unload=TRUE)
# Out:
# R[write to console]: Error in detach("package:lubridate", unload = TRUE) :
#   invalid 'name' argument
# Error in detach("package:lubridate", unload = TRUE) :
#   invalid 'name' argument
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/rpy2/ipython/rmagic.py in eval(self, code)
#     267                 # Need the newline in case the last line in code is a comment.
# --> 268                 value, visible = ro.r("withVisible({%s\n})" % code)
#     269             except (ri.embedded.RRuntimeError, ValueError) as exception:
#
# /usr/local/lib/python3.7/dist-packages/rpy2/robjects/__init__.py in __call__(self, string)
#     437         p = rinterface.parse(string)
# --> 438         res = self.eval(p)
#     439         return conversion.rpy2py(res)
#
# ...

# %%
# %%R
# .packages(TRUE)
# Out:
#   [1] "IRdisplay"     "IRkernel"      "pbdZMQ"        "repr"
#   [5] "askpass"       "assertthat"    "backports"     "base64enc"
#   [9] "bit"           "bit64"         "blob"          "brew"
#  [13] "brio"          "broom"         "cachem"        "callr"
#  [17] "cellranger"    "cli"           "clipr"         "colorspace"
#  [21] "commonmark"    "cpp11"         "crayon"        "credentials"
#  [25] "curl"          "data.table"    "DBI"           "dbplyr"
#  [29] "desc"          "devtools"      "diffobj"       "digest"
#  [33] "dplyr"         "dtplyr"        "ellipsis"      "evaluate"
#  [37] "fansi"         "farver"        "fastmap"       "forcats"
#  [41] "fs"            "gargle"        "generics"      "gert"
#  [45] "ggplot2"       "gh"            "gitcreds"      "glue"
#  [49] "googledrive"   "googlesheets4" "gtable"        "haven"
#  [53] "highr"         "hms"           "htmltools"     "httr"
#  [57] "ids"           "ini"           "isoband"       "jquerylib"
# ...

# %%
# %%R
# detach("package:ggplot2")
# detach("package:tidyverse")                       # Detach stringr package
# Out:
# R[write to console]: Error in detach("package:tidyverse") : invalid 'name' argument
# Error in detach("package:tidyverse") : invalid 'name' argument
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/rpy2/ipython/rmagic.py in eval(self, code)
#     267                 # Need the newline in case the last line in code is a comment.
# --> 268                 value, visible = ro.r("withVisible({%s\n})" % code)
#     269             except (ri.embedded.RRuntimeError, ValueError) as exception:
#
# /usr/local/lib/python3.7/dist-packages/rpy2/robjects/__init__.py in __call__(self, string)
#     437         p = rinterface.parse(string)
# --> 438         res = self.eval(p)
#     439         return conversion.rpy2py(res)
#
# /usr/local/lib/python3.7/dist-packages/rpy2/robjects/functions.py in __call__(self, *args, **kwargs)
# ...

# %%
#save
# %%R
write_csv(ttnew,"totaltrip.csv")
